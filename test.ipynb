# %% [markdown]
# <a href="https://colab.research.google.com/github/thernandez0/is262a/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/College professional work/UCLA/Information Studies 262/Library_Usage.csv')
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 3                 SENIOR               28              13
# 1                 0                  ADULT               21              10
# 2                 0                  ADULT              275             559
# 3                 0                  ADULT               73              38
# 4                 0                  ADULT              182              90
#
#         Age Range Home Library Code Home Library Definition  \
# 0  65 to 74 years                 X            Main Library
# 1  55 to 59 years                 X            Main Library
# 2  60 to 64 years                 X            Main Library
# 3  45 to 54 years                M8             Mission Bay
# 4  45 to 54 years                 X            Main Library
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# ...

# %%
import matplotlib.pyplot as plt

df["Year Patron Registered"].value_counts().plot(kind="pie")
plt.show()

# %%
df["Circulation Active Month"].value_counts().plot(
    kind="bar",
    color=["skyblue"]
)

plt.title("Library Circulation Activity by Month")
plt.ylabel("Number of Circulations")
plt.xlabel("Month")
plt.show()
